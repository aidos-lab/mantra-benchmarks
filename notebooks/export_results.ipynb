# %%
import pandas as pd 
import wandb
wandb.login()
api = wandb.Api()

# Project is specified by <entity/project-name>
runs = api.runs("mantra-dev")

# %%
full_history, config_list, name_list = [], [], []
for run in runs: 
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files
    # print(run.history())
    h = run._full_history()
    h = [ r | run.config for r in h]
    full_history.extend(h)

# %%
import json
with open("raw_results.json","w") as f:
    json.dump(full_history,f)

# %%
df = pd.DataFrame(full_history)
df = df.set_index([ "task","model_name","node_features", "run_id"],inplace=False)
mean_df = df.groupby(level=[0,1,2]).mean()
mean_df = mean_df.add_suffix("_mean")

# %%
df
# Out:
#                                                                        trainer/global_step  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                                     4
#                                  NaN                                                     4
#                                  NaN                                                     9
#                                  NaN                                                     9
#                                  NaN                                                    14
# ...                                                                                    ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1                  239
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                  244
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                  244
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                  249
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                  249
#
#                                                                        _step  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                       0
#                                  NaN                                       1
#                                  NaN                                       2
#                                  NaN                                       3
#                                  NaN                                       4
# ...                                                                      ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1     95
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1     96
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1     97
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1     98
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1     99
#
#                                                                         _runtime  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                    2.732875
#                                  NaN                                    2.741454
#                                  NaN                                    3.095263
#                                  NaN                                    3.103196
#                                  NaN                                    3.445073
# ...                                                                          ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1  18.725717
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1  19.073730
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1  19.081988
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1  19.536976
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1  19.548454
#
#                                                                        validation_loss  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                          1.588308
#                                  NaN                                               NaN
#                                  NaN                                          1.588537
#                                  NaN                                               NaN
#                                  NaN                                          1.559772
# ...                                                                                ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1              NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1         0.301881
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1              NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1         0.305766
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1              NaN
#
#                                                                        epoch  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                       0
#                                  NaN                                       0
#                                  NaN                                       1
#                                  NaN                                       1
#                                  NaN                                       2
# ...                                                                      ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1     47
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1     48
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1     48
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1     49
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1     49
#
#                                                                        validation_accuracy  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                              0.314685
#                                  NaN                                                   NaN
#                                  NaN                                              0.223776
#                                  NaN                                                   NaN
#                                  NaN                                              0.286713
# ...                                                                                    ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1                  NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1             0.727273
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                  NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1             0.727273
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                  NaN
#
#                                                                          _timestamp  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                   1.718028e+09
#                                  NaN                                   1.718028e+09
#                                  NaN                                   1.718028e+09
#                                  NaN                                   1.718028e+09
#                                  NaN                                   1.718028e+09
# ...                                                                             ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1  1.718028e+09
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1  1.718028e+09
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1  1.718028e+09
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1  1.718028e+09
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1  1.718028e+09
#
#                                                                        train_accuracy  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                              NaN
#                                  NaN                                         0.244288
#                                  NaN                                              NaN
#                                  NaN                                         0.247803
#                                  NaN                                              NaN
# ...                                                                               ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1        0.697715
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1             NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1        0.702988
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1             NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1        0.715290
#
#                                                                        train_loss  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                          NaN
#                                  NaN                                     1.610316
#                                  NaN                                          NaN
#                                  NaN                                     1.587551
#                                  NaN                                          NaN
# ...                                                                           ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1    0.326739
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1         NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1    0.319854
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1         NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1    0.320104
#
#                                                                        validation_accuracy_betti_1  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                                           NaN
#                                  NaN                                                           NaN
#                                  NaN                                                           NaN
#                                  NaN                                                           NaN
#                                  NaN                                                           NaN
# ...                                                                                            ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#
#                                                                        validation_accuracy_betti_2  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                                           NaN
#                                  NaN                                                           NaN
#                                  NaN                                                           NaN
#                                  NaN                                                           NaN
#                                  NaN                                                           NaN
# ...                                                                                            ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#
#                                                                        validation_accuracy_betti_0  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                                           NaN
#                                  NaN                                                           NaN
#                                  NaN                                                           NaN
#                                  NaN                                                           NaN
#                                  NaN                                                           NaN
# ...                                                                                            ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                          NaN
#
#                                                                        train_accuracy_betti_2  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                                      NaN
#                                  NaN                                                      NaN
#                                  NaN                                                      NaN
#                                  NaN                                                      NaN
#                                  NaN                                                      NaN
# ...                                                                                       ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#
#                                                                        train_accuracy_betti_1  \
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                                      NaN
#                                  NaN                                                      NaN
#                                  NaN                                                      NaN
#                                  NaN                                                      NaN
#                                  NaN                                                      NaN
# ...                                                                                       ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#
#                                                                        train_accuracy_betti_0
# task model_name node_features    run_id
# NaN  NaN        NaN              NaN                                                      NaN
#                                  NaN                                                      NaN
#                                  NaN                                                      NaN
#                                  NaN                                                      NaN
#                                  NaN                                                      NaN
# ...                                                                                       ...
# name GCN        degree_transform f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#                                  f07009d1-305d-42ba-86fd-4924e3c6e2c1                     NaN
#
# [2080 rows x 15 columns]

# %%
std_df = df.groupby(level=[0,1,2]).std()
std_df = std_df.add_suffix("_std")

# %%
res_df = pd.concat([mean_df,std_df],join="outer",axis=1)

# %%
res_df.to_csv("results.csv")

# %%
res_df
# Out:
#                                                   trainer/global_step_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                126.500000
# name          GCN        degree_transform                       124.918367
# orientability GAT        degree_transform_onehot                126.500000
#                          random_node_features                   126.500000
#
#                                                   _step_mean  _runtime_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot   49.500000      12.247848
# name          GCN        degree_transform          48.867347      11.322112
# orientability GAT        degree_transform_onehot   49.500000      12.424127
#                          random_node_features      49.500000      11.784561
#
#                                                   validation_loss_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot              0.117399
# name          GCN        degree_transform                     0.826583
# orientability GAT        degree_transform_onehot              0.445250
#                          random_node_features                 0.589123
#
#                                                   epoch_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot   24.500000
# name          GCN        degree_transform          24.183673
# orientability GAT        degree_transform_onehot   24.500000
#                          random_node_features      24.500000
#
#                                                   validation_accuracy_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                       NaN
# name          GCN        degree_transform                         0.596061
# orientability GAT        degree_transform_onehot                  0.809538
#                          random_node_features                     0.726573
#
#                                                   _timestamp_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot     1.718028e+09
# name          GCN        degree_transform            1.718028e+09
# orientability GAT        degree_transform_onehot     1.718028e+09
#                          random_node_features        1.718028e+09
#
#                                                   train_accuracy_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                  NaN
# name          GCN        degree_transform                    0.584075
# orientability GAT        degree_transform_onehot             0.812239
#                          random_node_features                0.727550
#
#                                                   train_loss_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot         0.145672
# name          GCN        degree_transform                0.909987
# orientability GAT        degree_transform_onehot         0.424829
#                          random_node_features            0.592394
#
#                                                   validation_accuracy_betti_1_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                          0.784811
# name          GCN        degree_transform                                      NaN
# orientability GAT        degree_transform_onehot                               NaN
#                          random_node_features                                  NaN
#
#                                                   ...  \
# task          model_name node_features            ...
# betti_numbers GAT        degree_transform_onehot  ...
# name          GCN        degree_transform         ...
# orientability GAT        degree_transform_onehot  ...
#                          random_node_features     ...
#
#                                                   validation_accuracy_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                      NaN
# name          GCN        degree_transform                        0.225492
# orientability GAT        degree_transform_onehot                 0.031744
#                          random_node_features                    0.005684
#
#                                                   _timestamp_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot       43.753686
# name          GCN        degree_transform              37.466069
# orientability GAT        degree_transform_onehot       39.812265
#                          random_node_features          37.197905
#
#                                                   train_accuracy_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                 NaN
# name          GCN        degree_transform                   0.198743
# orientability GAT        degree_transform_onehot            0.027704
#                          random_node_features               0.009494
#
#                                                   train_loss_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot        0.081715
# name          GCN        degree_transform               0.773734
# orientability GAT        degree_transform_onehot        0.074352
#                          random_node_features           0.010065
#
#                                                   validation_accuracy_betti_1_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                         0.067136
# name          GCN        degree_transform                                     NaN
# orientability GAT        degree_transform_onehot                              NaN
#                          random_node_features                                 NaN
#
#                                                   validation_accuracy_betti_2_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                         0.051159
# name          GCN        degree_transform                                     NaN
# orientability GAT        degree_transform_onehot                              NaN
#                          random_node_features                                 NaN
#
#                                                   validation_accuracy_betti_0_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                           0.0596
# name          GCN        degree_transform                                     NaN
# orientability GAT        degree_transform_onehot                              NaN
#                          random_node_features                                 NaN
#
#                                                   train_accuracy_betti_2_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                    0.036873
# name          GCN        degree_transform                                NaN
# orientability GAT        degree_transform_onehot                         NaN
#                          random_node_features                            NaN
#
#                                                   train_accuracy_betti_1_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                    0.079048
# name          GCN        degree_transform                                NaN
# orientability GAT        degree_transform_onehot                         NaN
#                          random_node_features                            NaN
#
#                                                   train_accuracy_betti_0_std
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                    0.085722
# name          GCN        degree_transform                                NaN
# orientability GAT        degree_transform_onehot                         NaN
#                          random_node_features                            NaN
#
# [4 rows x 30 columns]

# %%
res_df[["validation_accuracy_mean",
        "validation_accuracy_std",
       "train_accuracy_mean", 
       "train_accuracy_std", 
       "validation_accuracy_betti_0_mean", 
       "validation_accuracy_betti_0_std", 
       "validation_accuracy_betti_1_mean", 
       "validation_accuracy_betti_1_std", 
       "validation_accuracy_betti_2_mean",
       "validation_accuracy_betti_2_std",
       "train_accuracy_betti_0_mean",
       "train_accuracy_betti_0_std",
       "train_accuracy_betti_1_mean", 
       "train_accuracy_betti_1_std", 
       "train_accuracy_betti_2_mean",
       "train_accuracy_betti_2_std",
       ]]
# Out:
#                                                   validation_accuracy_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                       NaN
# name          GCN        degree_transform                         0.596061
# orientability GAT        degree_transform_onehot                  0.809538
#                          random_node_features                     0.726573
#
#                                                   validation_accuracy_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                      NaN
# name          GCN        degree_transform                        0.225492
# orientability GAT        degree_transform_onehot                 0.031744
#                          random_node_features                    0.005684
#
#                                                   train_accuracy_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                  NaN
# name          GCN        degree_transform                    0.584075
# orientability GAT        degree_transform_onehot             0.812239
#                          random_node_features                0.727550
#
#                                                   train_accuracy_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                 NaN
# name          GCN        degree_transform                   0.198743
# orientability GAT        degree_transform_onehot            0.027704
#                          random_node_features               0.009494
#
#                                                   validation_accuracy_betti_0_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                           0.99435
# name          GCN        degree_transform                                      NaN
# orientability GAT        degree_transform_onehot                               NaN
#                          random_node_features                                  NaN
#
#                                                   validation_accuracy_betti_0_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                           0.0596
# name          GCN        degree_transform                                     NaN
# orientability GAT        degree_transform_onehot                              NaN
#                          random_node_features                                 NaN
#
#                                                   validation_accuracy_betti_1_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                          0.784811
# name          GCN        degree_transform                                      NaN
# orientability GAT        degree_transform_onehot                               NaN
#                          random_node_features                                  NaN
#
#                                                   validation_accuracy_betti_1_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                         0.067136
# name          GCN        degree_transform                                     NaN
# orientability GAT        degree_transform_onehot                              NaN
#                          random_node_features                                 NaN
#
#                                                   validation_accuracy_betti_2_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                          0.802573
# name          GCN        degree_transform                                      NaN
# orientability GAT        degree_transform_onehot                               NaN
#                          random_node_features                                  NaN
#
#                                                   validation_accuracy_betti_2_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                         0.051159
# name          GCN        degree_transform                                     NaN
# orientability GAT        degree_transform_onehot                              NaN
#                          random_node_features                                 NaN
#
#                                                   train_accuracy_betti_0_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                     0.977483
# name          GCN        degree_transform                                 NaN
# orientability GAT        degree_transform_onehot                          NaN
#                          random_node_features                             NaN
#
#                                                   train_accuracy_betti_0_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                    0.085722
# name          GCN        degree_transform                                NaN
# orientability GAT        degree_transform_onehot                         NaN
#                          random_node_features                            NaN
#
#                                                   train_accuracy_betti_1_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                      0.73226
# name          GCN        degree_transform                                 NaN
# orientability GAT        degree_transform_onehot                          NaN
#                          random_node_features                             NaN
#
#                                                   train_accuracy_betti_1_std  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                    0.079048
# name          GCN        degree_transform                                NaN
# orientability GAT        degree_transform_onehot                         NaN
#                          random_node_features                            NaN
#
#                                                   train_accuracy_betti_2_mean  \
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                     0.784759
# name          GCN        degree_transform                                 NaN
# orientability GAT        degree_transform_onehot                          NaN
#                          random_node_features                             NaN
#
#                                                   train_accuracy_betti_2_std
# task          model_name node_features
# betti_numbers GAT        degree_transform_onehot                    0.036873
# name          GCN        degree_transform                                NaN
# orientability GAT        degree_transform_onehot                         NaN
#                          random_node_features                            NaN
