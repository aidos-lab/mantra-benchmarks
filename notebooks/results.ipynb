# %%
import sys 
import os 

sys.path.append("..")
os.chdir("..")

# %%
from experiments.vis import ResultHandler
from experiments.vis.overview_barplot import overview_barplot

# %%
result= ResultHandler()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: danielbinschmid (danielbinschmid_binbash). Use `wandb login --relogin` to force relogin
# /home/binbash/master/aidos/MANTRA/experiments/vis/result_handler.py:87: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   reshaped_df = pd.concat([reshaped_df, new_row], ignore_index=True)

# %%
overview_barplot(result)
# Out:
# /home/binbash/master/aidos/MANTRA/experiments/vis/overview_barplot.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels( ['','betti_0', 'betti_1', 'betti_2', '','name', 'orientability'])
